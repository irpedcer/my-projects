# %% [markdown]
# ## Connect to database file

# %%
# %%capture
# %load_ext sql
# %sql sqlite:///chinook.db
# Out:
# 'Connected: None@chinook.db'

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Tables and views on database

# %%
# %%sql
#
# SELECT
#     name,
#     type
# FROM sqlite_master
# WHERE type IN ("table","view");
# Out:
# Done.
# [('album', 'table'),
#  ('artist', 'table'),
#  ('customer', 'table'),
#  ('employee', 'table'),
#  ('genre', 'table'),
#  ('invoice', 'table'),
#  ('invoice_line', 'table'),
#  ('media_type', 'table'),
#  ('playlist', 'table'),
#  ('playlist_track', 'table'),
#  ('track', 'table')]

# %% [markdown]
# Here is also the database schema
#
# ![Here is also the database schema](https://s3.amazonaws.com/dq-content/191/chinook-schema.svg)

# %% [markdown]
# ## Genres that sell most tracks in the US

# %%
# %%sql
#
# WITH tracks_sold_in_USA AS
#      (
#       SELECT il.*
#       FROM invoice_line il
#       INNER JOIN invoice i ON i.invoice_id = il.invoice_id
#       INNER JOIN customer c ON c.customer_id = i.customer_id
#       WHERE c.country = "USA"
#      )
#
#
# SELECT
#     g.name genre,
#     count(tusa.invoice_line_id) tracks_sold,
#     round(cast(count(tusa.invoice_line_id) AS FLOAT) / (
#      SELECT COUNT(*)
#             FROM tracks_sold_in_USA)
#           ,4)
#      percentage_sold
# FROM tracks_sold_in_usa tusa
# INNER JOIN track t on t.track_id = tusa.track_id
# INNER JOIN genre g on g.genre_id = t.genre_id
# GROUP BY 1
# ORDER BY 2 DESC;
# Out:
# Done.
# [('Rock', 561, 0.5338),
#  ('Alternative & Punk', 130, 0.1237),
#  ('Metal', 124, 0.118),
#  ('R&B/Soul', 53, 0.0504),
#  ('Blues', 36, 0.0343),
#  ('Alternative', 35, 0.0333),
#  ('Latin', 22, 0.0209),
#  ('Pop', 22, 0.0209),
#  ('Hip Hop/Rap', 20, 0.019),
#  ('Jazz', 14, 0.0133),
#  ('Easy Listening', 13, 0.0124),
#  ('Reggae', 6, 0.0057),
#  ('Electronica/Dance', 5, 0.0048),
#  ('Classical', 4, 0.0038),
#  ('Heavy Metal', 3, 0.0029),
#  ('Soundtrack', 2, 0.0019),
#  ('TV Shows', 1, 0.001)]

# %% [markdown]
# The three arists are chosen based on the most sold genres in the US.
#  1st - Red Tone - Punk - Percentage of genre sold in US: 53.38%
#  2nd - Slim Jim Bites - Blues - Percentage of genre sold in US: 3.43%
#  3rd - Meteor and the Girls - Pop - Percentage of genre sold in US: 2.09%

# %% [markdown]
# ### Total amount of sales by sales support agent

# %%
# %%sql
# SELECT
# e.employee_id ID,
# e.first_name || " " || e.last_name as Name,
# e.country as Country,
# e.hire_date,
# ROUND(sum(i.total),2) total_sales
# FROM customer c
# INNER JOIN invoice i ON i.customer_id = c.customer_id
# INNER JOIN employee e ON e.employee_id = c.support_rep_id
# group by 2;
# Out:
# Done.
# [(3, 'Jane Peacock', 'Canada', '2017-04-01 00:00:00', 1731.51),
#  (4, 'Margaret Park', 'Canada', '2017-05-03 00:00:00', 1584.0),
#  (5, 'Steve Johnson', 'Canada', '2017-10-17 00:00:00', 1393.92)]

# %% [markdown]
# Looking only and the total_sales column, we can see that Jane is the agent with the biggest amount of sales. But the hiring date allows us to correctly interpret these results.
#
# While her and Margaret may have the same performance (Jane's sales 9.3% bigger than Margaret's with the latter entering 1 month later the company) Steve has proven to be the best performer. That is because even though he has 24% less of sales than Jane, he entered the company 6 months later!

# %% [markdown]
# ### Analyze Sales by Country

# %%
# %%sql
#
# WITH country_or_other AS
#     (
#      SELECT CASE
#            WHEN (SELECT COUNT(*)
#                         FROM customer
#                         WHERE country = c.country) = 1 THEN "Other"
#            ELSE c.country
#         END AS country,
#         c.customer_id,
#         il.*
#         FROM customer c
#         INNER JOIN invoice i ON i.customer_id = c.customer_id
#         INNER JOIN invoice_line il ON il.invoice_id = i.invoice_id
#      )
#
# SELECT country,
#        customers,
#        total_sales,
#        avg_sales_customer,
#        avg_order_value
#     FROM (SELECT country,
#                  count(distinct customer_id) customers,
#                  sum(unit_price) total_sales,
#                  sum(unit_price)/count(customer_id) avg_sales_customer,
#                  sum(unit_price)/count(invoice_id) avg_order_value,
#                  CASE
#                      WHEN country = "Other" THEN 1
#                      ELSE 0
#                      END AS sort
#           FROM country_or_other
#     GROUP BY 1
#     ORDER BY sort ASC, total_sales DESC
#     );
# Out:
# Done.
# [('USA', 13, 1040.490000000008, 0.9900000000000075, 0.9900000000000075),
#  ('Canada', 8, 535.5900000000034, 0.9900000000000063, 0.9900000000000063),
#  ('Brazil', 5, 427.68000000000245, 0.9900000000000057, 0.9900000000000057),
#  ('France', 5, 389.0700000000021, 0.9900000000000053, 0.9900000000000053),
#  ('Germany', 4, 334.6200000000016, 0.9900000000000048, 0.9900000000000048),
#  ('Czech Republic', 2, 273.24000000000103, 0.9900000000000038, 0.9900000000000038),
#  ('United Kingdom', 3, 245.52000000000078, 0.9900000000000031, 0.9900000000000031),
#  ('Portugal', 2, 185.13000000000022, 0.9900000000000012, 0.9900000000000012),
#  ('India', 2, 183.1500000000002, 0.9900000000000011, 0.9900000000000011),
#  ('Other', 15, 1094.9400000000085, 0.9900000000000077, 0.9900000000000077)]

# %% [markdown]
# ### Number and percentage of album purchases

# %%
# %%sql
# WITH invoice_first_track AS
#      (
#       SELECT invoice_id,
#              MIN(track_id) first_track_id
#              FROM invoice_line
#          GROUP BY 1
#      )
#
#
# SELECT album_purchase,
#        COUNT(invoice_id) total_invoices,
#        CAST(COUNT(invoice_id) AS FLOAT) / (SELECT COUNT(*)
#                             FROM invoice) percent
#         FROM
#         (SELECT ift.*,
#                 CASE
#                     WHEN (   SELECT t.track_id FROM track t
#                              WHERE t.album_id = (SELECT t2.album_id FROM track t2
#                                              WHERE t2.track_id = ift.first_track_id)
#
#
#                        EXCEPT
#                               SELECT il.track_id FROM invoice_line il
#                               WHERE il.invoice_id = ift.invoice_id
#                           ) IS NULL
#                     AND
#                         (      SELECT il.track_id FROM invoice_line il
#                                WHERE il.invoice_id = ift.invoice_id
#
#                          EXCEPT
#
#                             SELECT t.track_id FROM track t
#                             WHERE t.album_id = (SELECT t2.album_id FROM track t2
#                                              WHERE t2.track_id = ift.first_track_id)
#                          ) IS NULL
#                     THEN "Yes"
#                     ELSE "No"
#                 END AS album_purchase
#            FROM invoice_first_track ift)
#          GROUP BY album_purchase
# Out:
# Done.
# [('No', 500, 0.8143322475570033), ('Yes', 114, 0.18566775244299674)]

# %% [markdown]
# I wouldn't advice to remove full album purchases since full-album purchases represent almost 20% of invoice.

# %% [markdown]
# ### Most used artist in playlists

# %%
# %%sql
#
# SELECT ar.name,
#        COUNT(distinct pt.playlist_id) number_of_playlists,
#        COUNT(distinct pt.track_id) number_of_tracks
# FROM playlist_track pt
# INNER JOIN track t ON t.track_id = pt.track_id
# INNER JOIN album al ON al.album_id = t.album_id
# INNER JOIN artist ar ON ar.artist_id = al.artist_id
# GROUP BY 1
# ORDER BY 2 DESC, 3 DESC
# Out:
# Done.
# [('Eugene Ormandy', 7, 3),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 6, 3),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 6, 2),
#  ('English Concert & Trevor Pinnock', 6, 2),
#  ("The King's Singers", 6, 2),
#  ('Michael Tilson Thomas & San Francisco Symphony', 5, 2),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 5, 1),
#  ('Adrian Leaper & Doreen de Feis', 5, 1),
#  ('Alberto Turco & Nova Schola Gregoriana', 5, 1),
#  ('Antal Doráti & London Symphony Orchestra', 5, 1),
#  ('Barry Wordsworth & BBC Concert Orchestra', 5, 1),
#  ('Berliner Philharmoniker & Hans Rosbaud', 5, 1),
#  ('Boston Symphony Orchestra & Seiji Ozawa', 5, 1),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 5, 1),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 5, 1),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 5, 1),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 5, 1),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 5, 1),
#  ('Gustav Mahler', 5, 1),
#  ('James Levine', 5, 1),
#  ('Julian Bream', 5, 1),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", 5, 1),
#  ('Luciano Pavarotti', 5, 1),
#  ('Martin Roscoe', 5, 1),
#  ('Maurizio Pollini', 5, 1),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 5, 1),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 5, 1),
#  ('Philharmonia Orchestra & Sir Neville Marriner', 5, 1),
#  ('Philip Glass Ensemble', 5, 1),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', 5, 1),
#  ('Scholars Baroque Ensemble', 5, 1),
#  ('Sir Georg Solti & Wiener Philharmoniker', 5, 1),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 5, 1),
#  ('Ton Koopman', 5, 1),
#  ('Wilhelm Kempff', 5, 1),
#  ('Yo-Yo Ma', 5, 1),
#  ('Iron Maiden', 4, 213),
#  ('Metallica', 4, 112),
#  ('Pearl Jam', 4, 67),
#  ('Eric Clapton', 4, 48),
#  ('Chico Buarque', 4, 34),
#  ('Gilberto Gil', 4, 32),
#  ('Ozzy Osbourne', 4, 32),
#  ('Nirvana', 4, 29),
#  ('Djavan', 4, 26),
#  ('Caetano Veloso', 4, 21),
#  ('Mötley Crüe', 4, 17),
#  ('Soundgarden', 4, 17),
#  ('Gonzaguinha', 4, 14),
#  ('Alice In Chains', 4, 12),
#  ('Stone Temple Pilots', 4, 12),
#  ('Temple of the Dog', 4, 10),
#  ('Accept', 4, 4),
#  ('Aaron Copland & London Symphony Orchestra', 4, 1),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 4, 1),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 4, 1),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 4, 1),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 4, 1),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 4, 1),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 4, 1),
#  ('Choir Of Westminster Abbey & Simon Preston', 4, 1),
#  ("Christopher O'Riley", 4, 1),
#  ('Edo de Waart & San Francisco Symphony', 4, 1),
#  ('Emerson String Quartet', 4, 1),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 4, 1),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 4, 1),
#  ('Fretwork', 4, 1),
#  ('Gerald Moore', 4, 1),
#  ('Göteborgs Symfoniker & Neeme Järvi', 4, 1),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 4, 1),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 4, 1),
#  ('Itzhak Perlman', 4, 1),
#  ('Leonard Bernstein & New York Philharmonic', 4, 1),
#  ('Les Arts Florissants & William Christie', 4, 1),
#  ('London Symphony Orchestra & Sir Charles Mackerras', 4, 1),
#  ('Michele Campanella', 4, 1),
#  ('Nash Ensemble', 4, 1),
#  ('Orchestra of The Age of Enlightenment', 4, 1),
#  ('Otto Klemperer & Philharmonia Orchestra', 4, 1),
#  ('Roger Norrington, London Classical Players', 4, 1),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 4, 1),
#  ('Sergei Prokofiev & Yuri Temirkanov', 4, 1),
#  ('The 12 Cellists of The Berlin Philharmonic', 4, 1),
#  ('Yehudi Menuhin', 4, 1),
#  ('U2', 3, 135),
#  ('Led Zeppelin', 3, 114),
#  ('Deep Purple', 3, 92),
#  ('Lenny Kravitz', 3, 57),
#  ('Faith No More', 3, 52),
#  ('Van Halen', 3, 52),
#  ('Os Paralamas Do Sucesso', 3, 49),
#  ('Red Hot Chili Peppers', 3, 48),
#  ('Queen', 3, 45),
#  ('Foo Fighters', 3, 44),
#  ("Guns N' Roses", 3, 42),
#  ('R.E.M.', 3, 41),
#  ('The Rolling Stones', 3, 41),
#  ('Audioslave', 3, 40),
#  ('Titãs', 3, 38),
#  ('Miles Davis', 3, 37),
#  ('Chico Science & Nação Zumbi', 3, 36),
#  ('Kiss', 3, 35),
#  ('Green Day', 3, 34),
#  ('Smashing Pumpkins', 3, 34),
#  ('Jamiroquai', 3, 32),
#  ('Antônio Carlos Jobim', 3, 31),
#  ('Cidade Negra', 3, 31),
#  ('Legião Urbana', 3, 31),
#  ('Cássia Eller', 3, 30),
#  ('The Cult', 3, 30),
#  ('Tim Maia', 3, 30),
#  ('Santana', 3, 27),
#  ('Milton Nascimento', 3, 26),
#  ('The Tea Party', 3, 26),
#  ('Skank', 3, 23),
#  ('Spyro Gyra', 3, 21),
#  ('James Brown', 3, 20),
#  ('House Of Pain', 3, 19),
#  ('Zeca Pagodinho', 3, 19),
#  ('AC/DC', 3, 18),
#  ('The Clash', 3, 18),
#  ('Black Sabbath', 3, 17),
#  ('Body Count', 3, 17),
#  ('Def Leppard', 3, 16),
#  ('Funk Como Le Gusta', 3, 16),
#  ('Judas Priest', 3, 16),
#  ('Planet Hemp', 3, 16),
#  ('Aerosmith', 3, 15),
#  ('Motörhead', 3, 15),
#  ('Ed Motta', 3, 14),
#  ('Elis Regina', 3, 14),
#  ('Falamansa', 3, 14),
#  ('Jorge Ben', 3, 14),
#  ('Passengers', 3, 14),
#  ('Rush', 3, 14),
#  ('The Police', 3, 14),
#  ('UB40', 3, 14),
#  ('Alanis Morissette', 3, 13),
#  ('Incognito', 3, 13),
#  ('BackBeat', 3, 12),
#  ('Jota Quest', 3, 12),
#  ('Page & Plant', 3, 12),
#  ('Scorpions', 3, 12),
#  ('Bruce Dickinson', 3, 11),
#  ('R.E.M. Feat. Kate Pearson', 3, 11),
#  ('Joe Satriani', 3, 10),
#  ('Raimundos', 3, 10),
#  ('Apocalyptica', 3, 8),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', 3, 7),
#  ('Habib Koité and Bamada', 3, 2),
#  ('Dread Zeppelin', 3, 1),
#  ('Nicolaus Esterhazy Sinfonia', 3, 1),
#  ('Lost', 2, 92),
#  ('Various Artists', 2, 56),
#  ('The Office', 2, 53),
#  ('Creedence Clearwater Revival', 2, 40),
#  ('Lulu Santos', 2, 28),
#  ('Battlestar Galactica (Classic)', 2, 24),
#  ('Frank Sinatra', 2, 24),
#  ('Amy Winehouse', 2, 23),
#  ('Heroes', 2, 23),
#  ('Gene Krupa', 2, 22),
#  ('Battlestar Galactica', 2, 20),
#  ('The Who', 2, 20),
#  ('The Black Crowes', 2, 19),
#  ('Black Label Society', 2, 18),
#  ('Marisa Monte', 2, 18),
#  ('Marvin Gaye', 2, 18),
#  ('Jimi Hendrix', 2, 17),
#  ('Marcos Valle', 2, 17),
#  ('O Rappa', 2, 17),
#  ('O Terço', 2, 15),
#  ('Toquinho & Vinícius', 2, 15),
#  ('Vinícius De Moraes', 2, 15),
#  ('Chris Cornell', 2, 14),
#  ('João Suplicy', 2, 14),
#  ('Olodum', 2, 14),
#  ('Os Mutantes', 2, 14),
#  ('Raul Seixas', 2, 14),
#  ('JET', 2, 13),
#  ('Velvet Revolver', 2, 13),
#  ('David Coverdale', 2, 12),
#  ('Godsmack', 2, 12),
#  ('Mônica Marianno', 2, 12),
#  ('Buddy Guy', 2, 11),
#  ('System Of A Down', 2, 11),
#  ('The Doors', 2, 11),
#  ('Cláudio Zoli', 2, 10),
#  ('Marillion', 2, 10),
#  ('Men At Work', 2, 10),
#  ("Paul D'Ianno", 2, 10),
#  ('Stevie Ray Vaughan & Double Trouble', 2, 10),
#  ('Dennis Chambers', 2, 9),
#  ('Frank Zappa & Captain Beefheart', 2, 9),
#  ('Pink Floyd', 2, 9),
#  ('Billy Cobham', 2, 8),
#  ('Aisha Duo', 2, 2),
#  ('Karsh Kale', 2, 2),
#  ('The Posies', 2, 2),
#  ('Aaron Goldberg', 2, 1),
#  ('Aquaman', 2, 1),
#  ('Cake', 2, 1),
#  ('Calexico', 2, 1),
#  ('Luciana Souza/Romero Lubambo', 2, 1)]

# %% [markdown]
# ### Tracks purchased vs non purchased

# %% [markdown]
# In order to do this we need to now:
# * Number of total tracks in the app --> total_tracks
# * Number of distinct tracks in invoice_line --> tracks_purchased

# %%
# %%sql
#
# SELECT (SELECT count(distinct track_id) FROM invoice_line) tracks_purchased,
#        count(distinct track_id) - (SELECT count(distinct track_id) FROM invoice_line) tracks_non_purchaded,
#        ROUND((SELECT count(distinct track_id) FROM invoice_line)/CAST(count(distinct track_id) AS FLOAT), 3) *100 percentage,
#        count(distinct track_id) total_tracks
# FROM track
# Out:
# Done.
# [(1806, 1697, 51.6, 3503)]

# %% [markdown]
# 51.6% of the tracks available have been sold.

# %% [markdown]
# ### Protected vs non-protected media types. Effect on sales.

# %% [markdown]
# * Tenemos que crearnos una tabla donde estén todas las tracks compradas diciendo si son protected o non-protected. Para ello clasificamos los 5 tipos de media_type_id
#  1,4,5 - NO PROTECTED
#  2,3 - PROTECTED
#
# * A partir de ahí solo tenemos que sumar las ventas cada parte aplicando un WHERE para distinguir las dos posibilidades y sacar los porcentajes

# %%
# %%sql
#
# WITH protected_track_sales AS
#      (
#          SELECT COUNT(il.track_id) protected_tracks_bought,
#                 SUM(il.unit_price) protected_sales
#         FROM invoice_line il
#         INNER JOIN track t on t.track_id = il.track_id
#         INNER JOIN media_type mt on mt.media_type_id = t.media_type_id
#         WHERE mt.media_type_id = 2
#               OR mt.media_type_id = 3
#
#         ORDER BY 1 ASC
#
#      )
#
# SELECT (SELECT protected_tracks_bought FROM protected_track_sales) protected_tracks_sold,
#        (SELECT protected_sales FROM protected_track_sales) protected_sales,
#         SUM(unit_price) total_sales,
#        (SELECT protected_sales FROM protected_track_sales)/SUM(unit_price) * 100 percentage
#
#  FROM invoice_line
# Out:
# Done.
# [(442, 437.58000000000254, 4709.429999999431, 9.291570317428127)]

# %% [markdown]
# Protected sales are not really popular, representing roughly 9.30% of total sales.
